# %%
import numpy as np
import matplotlib.pyplot as plt
freq = np.linspace(1e-5, 1, 50000)
u_oms=((1+(2E-3/freq)**4))
u_therm=((1+((2*1.414)*1e-3/freq)**4))
# Added power law stability factor
u_KN=1e-3/freq
u_oms_ASD=u_oms**0.5
u_therm_ASD=u_therm**0.5
u_KN_ASD=u_KN**0.5
# PMON uses nominal power allocation = 100 µW
PMON_stability_base=1e-4
# PMON Total dissipation
PMON_dissipation=PMON_stability_base*u_oms_ASD
PMON_dissipation_KN=PMON_stability_base*u_oms_ASD*u_KN_ASD
PMON_temp_stability_KN=0.1*u_oms_ASD*u_KN_ASD
PMON_temp_stability_old=0.1*u_oms_ASD

# %%
plt.figure(figsize=(10,8))
plt.plot(freq, u_oms_ASD, 'r-',label = "√(1+(2mHz/f)^4): OMS")
plt.plot(freq, u_therm_ASD, 'b-',label = "√(1+(2√2mHz/f)^4: Thermal)")
plt.plot(freq, u_KN, 'g--',label = "1mHz/f")
plt.plot(freq, u_KN_ASD, 'g-',label = "√1mHz/f: KN Modification")
plt.plot(freq, PMON_dissipation, 'c-',label = "100µW/√Hz*√(1+(2mHz/f)^4): Old")
plt.plot(freq, PMON_dissipation_KN, 'k-',label = "100µW/√Hz*√(1+(2mHz/f)^4)*√1mHz/f: New")
plt.plot(freq,np.ones(np.shape(freq))*1e-4,'c-.', label = "100µW Baseline")
plt.title("PMON Thermal and Power Stability")
plt.yscale("log")
plt.xscale("log")
plt.xlim(1e-5, 1)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Thermal & Radiative Power Stability (W/√Hz)")
plt.legend()
plt.grid(visible=None, which='both', axis='both')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(freq, u_oms_ASD, 'r-',label = "√(1+(2mHz/f)^4): OMS")
plt.plot(freq, u_therm_ASD, 'b-',label = "√(1+(2√2mHz/f)^4: Thermal)")
plt.plot(freq, u_KN, 'g--',label = "1mHz/f")
plt.plot(freq, u_KN_ASD, 'g-',label = "√1mHz/f: KN Modification")
plt.plot(freq, PMON_dissipation_KN, 'k-',label = "100µW/√Hz*√(1+(2mHz/f)^4)*√1mHz/f: New")
plt.plot(freq,np.ones(np.shape(freq))*1e-4,'c-.', label = "100µW Baseline")
plt.title("PMON Thermal and Power Stability")
plt.yscale("log")
plt.xscale("log")
plt.xlim(1e-5, 1)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Thermal & Radiative Power Stability (W/√Hz)")
plt.legend()
plt.grid(visible=None, which='both', axis='both')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(freq, u_oms_ASD, 'r-',label = "√(1+(2mHz/f)^4): OMS")
plt.plot(freq, u_KN_ASD, 'g-',label = "√1mHz/f: KN's Additional Power Law Factor")
plt.plot(freq, PMON_dissipation_KN, 'k-',label = "100µW/√Hz*√(1+(2mHz/f)^4)*√1mHz/f: New")
plt.plot(freq,np.ones(np.shape(freq))*1e-4,'c-.', label = "100µW Baseline")
plt.title("PMON Thermal and Power Stability")
plt.yscale("log")
plt.xscale("log")
plt.xlim(1e-5, 1)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Thermal & Radiative Power Stability (W/√Hz)")
plt.legend()
plt.grid(visible=None, which='both', axis='both')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(freq, PMON_temp_stability_KN, 'b-',label = "0.1K/√Hz*√(1+(2mHz/f)^4)*√1mHz/f: New")
plt.plot(freq, PMON_temp_stability_old, 'r-',label = "0.1K/√Hz*√(1+(2mHz/f)^4): Old")
plt.plot(freq, u_KN_ASD, 'k--',label = "√1mHz/f: KN's Additional Power Law Factor")
plt.plot(freq,np.ones(np.shape(freq))*0.1,'g-', label = "0.1K Baseline")
plt.plot(freq,np.ones(np.shape(freq))*3e-3,'g--', label = "3mK")
plt.title("Thermal Stability")
plt.yscale("log")
plt.xscale("log")
plt.xlim(1e-5, 1)
plt.ylim(1e-3, 1e5)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Temperature Stability (K/√Hz)")
plt.legend()
plt.grid(visible=None, which='both', axis='both')
plt.show()
